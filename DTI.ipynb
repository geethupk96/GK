# %%
from sympy import symbols, diff, latex

# Define the symbols
x, y = symbols('x y')

# Define the polynomial function
polynomial = x**840*y**1470+ x**840*y**1575+ 3*x**1050*y**1386+ x**1050*y**1428+ x**1050*y**1050+ 2*x**1050*y**1350+ 2*x**1050*y**1500+ x**1134*y**1386+ x**1134*y**1428+ 2*x**1176*y**1260+ x**1176*y**1386+ 2*x**1350*y**1350+ x**1386*y**1764+ x**1386*y**1500+ 2*x**1260*y**1386+ x**1428*y**1470+ x**1575*y**1575+ 3*x**1500*y**1650+ x**1470*y**1680
# Calculate the derivatives
derivative_x = x*diff(polynomial, x)
derivative_y = y*diff(polynomial, y)

derivative_x2 = x*diff(derivative_x , x)
derivative_y2 = y*diff(derivative_y, y)
derivative_xy = y*diff(derivative_x , y)
# Add the derivatives
sum_of_derivatives = derivative_x + derivative_y
sum_of_derivatives2 = derivative_x2 + derivative_y2
sum_of_derivatives3 = derivative_x2 + derivative_y2 + 2*derivative_xy 

# Define a point to evaluate the derivative
point = {x: 1, y: 1}
# Evaluate the derivative at the point
value_at_point = sum_of_derivatives.subs(point)
value_at_point2 = sum_of_derivatives2.subs(point)
value_at_point3 = sum_of_derivatives3.subs(point)
value_at_point4 = derivative_xy.subs(point)
latex_polynomial = latex(polynomial)
latex_derivative_x = latex(derivative_x)
latex_derivative_y = latex(derivative_y)
latex_derivative_x2 = latex(derivative_x2)
latex_derivative_y2 = latex(derivative_y2)
latex_derivative_xy = latex(derivative_xy)
latex_sum_of_derivatives = latex(sum_of_derivatives)
latex_sum_of_derivatives2 = latex(sum_of_derivatives2)
latex_sum_of_derivatives3 = latex(sum_of_derivatives3)
latex_value_at_point = latex(value_at_point)
latex_value_at_point2 = latex(value_at_point2)
latex_value_at_point3 = latex(value_at_point3)
latex_value_at_point4 = latex(value_at_point4)
# Print the LaTeX representations
print(f"Original polynomial (LaTeX): ${latex_polynomial}$")
print(f"Derivative with respect to x (LaTeX): ${latex_derivative_x}$")
print(f"Derivative with respect to y (LaTeX): ${latex_derivative_y}$")
print(f"Derivative with respect to xy (LaTeX): ${latex_derivative_xy}$")
print(f"Derivative with respect to x2 (LaTeX): ${latex_derivative_x2}$")
print(f"Derivative with respect to y2 (LaTeX): ${latex_derivative_y2}$")
print(f"Sum of derivatives (LaTeX): ${latex_sum_of_derivatives}$")
print(f"Sum of derivatives2 (LaTeX): ${latex_sum_of_derivatives2}$")
print(f"Sum of derivatives3 (LaTeX): ${latex_sum_of_derivatives3}$")
print(f"Modified First Zagreb DTI : ${value_at_point}$")
print(f"Modified Forgotten DTI: ${value_at_point2}$")
print(f"Hyper DTI: ${value_at_point3}$")
print(f"Second Zagreb DTI: ${value_at_point4}$")
# Out:
# Original polynomial (LaTeX): $x^{1575} y^{1575} + 3 x^{1500} y^{1650} + x^{1470} y^{1680} + x^{1428} y^{1470} + x^{1386} y^{1764} + x^{1386} y^{1500} + 2 x^{1350} y^{1350} + 2 x^{1260} y^{1386} + x^{1176} y^{1386} + 2 x^{1176} y^{1260} + x^{1134} y^{1428} + x^{1134} y^{1386} + 2 x^{1050} y^{1500} + x^{1050} y^{1428} + 3 x^{1050} y^{1386} + 2 x^{1050} y^{1350} + x^{1050} y^{1050} + x^{840} y^{1575} + x^{840} y^{1470}$
# Derivative with respect to x (LaTeX): $x \left(1575 x^{1574} y^{1575} + 4500 x^{1499} y^{1650} + 1470 x^{1469} y^{1680} + 1428 x^{1427} y^{1470} + 1386 x^{1385} y^{1764} + 1386 x^{1385} y^{1500} + 2700 x^{1349} y^{1350} + 2520 x^{1259} y^{1386} + 1176 x^{1175} y^{1386} + 2352 x^{1175} y^{1260} + 1134 x^{1133} y^{1428} + 1134 x^{1133} y^{1386} + 2100 x^{1049} y^{1500} + 1050 x^{1049} y^{1428} + 3150 x^{1049} y^{1386} + 2100 x^{1049} y^{1350} + 1050 x^{1049} y^{1050} + 840 x^{839} y^{1575} + 840 x^{839} y^{1470}\right)$
# ...
